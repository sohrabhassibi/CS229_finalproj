# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.preprocessing import StandardScaler

# Import Moirai from Uni2TS
from uni2ts.model.moirai import MoiraiForecast  # or correct import path per your install
from uni2ts.eval_util.plot import plot_single
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[1], line 7
#       4 from sklearn.preprocessing import StandardScaler
#       6 # Import Moirai from Uni2TS
# ----> 7 from uni2ts.model.moirai import MoiraiForecast  # or correct import path per your install
#       8 from uni2ts.eval_util.plot import plot_single
#
# ModuleNotFoundError: No module named 'uni2ts'
